# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
import matplotlib.ticker as mticker
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates

# %%
stock_name = 'Axis Bank'
data = pd.read_csv('BSE_Data/'+stock_name+'.csv')
data['Date'] = pd.to_datetime(data['Date'])

# %%
data = data.loc[:,['Date','Open Price', 'High Price', 'Low Price', 'Close Price','No.of Shares']]
data.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price  No.of Shares
# 0 2019-07-31      694.00      695.35     657.65       674.40       1271110
# 1 2019-07-30      725.05      727.70     701.10       706.55        384131
# 2 2019-07-29      745.00      745.00     709.90       719.65        328200
# 3 2019-07-26      723.30      732.30     719.10       729.85        185928
# 4 2019-07-25      712.00      725.85     706.55       723.30        163417

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2510 entries, 0 to 2509
# Data columns (total 6 columns):
# Date            2510 non-null datetime64[ns]
# Open Price      2510 non-null float64
# High Price      2510 non-null float64
# Low Price       2510 non-null float64
# Close Price     2510 non-null float64
# No.of Shares    2510 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 117.7 KB

# %%
plot_data = data.copy()
plot_data.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price  No.of Shares
# 0 2019-07-31      694.00      695.35     657.65       674.40       1271110
# 1 2019-07-30      725.05      727.70     701.10       706.55        384131
# 2 2019-07-29      745.00      745.00     709.90       719.65        328200
# 3 2019-07-26      723.30      732.30     719.10       729.85        185928
# 4 2019-07-25      712.00      725.85     706.55       723.30        163417

# %%
plot_data['Date'] = [mdates.date2num(d) for d in plot_data['Date']]
quotes = plot_data.loc[:100,:].values
fig, ax = plt.subplots(figsize=(20,10))
candlestick_ohlc(ax, quotes, width=0.5, colorup='g', colordown='r');
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(stock_name)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

# %%
monthly_data = data.copy()
monthly_data.set_index(monthly_data["Date"],inplace=True)
monthly_data['Open Price'] = monthly_data['Open Price'].resample('M', how='first')
monthly_data['High Price'] = monthly_data['High Price'].resample('M', how='max')
monthly_data['Low Price'] = monthly_data['Low Price'].resample('M', how='min')
monthly_data['Close Price'] = monthly_data['Close Price'].resample('M', how='last')
monthly_data['No.of Shares'] = monthly_data['No.of Shares'].resample('M', how='sum')
monthly_data = monthly_data.dropna()
monthly_data.head()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).first()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).max()
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).min()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   import sys
#                  Date  Open Price  High Price  Low Price  Close Price  \
# Date
# 2019-07-31 2019-07-31      810.00      819.05     657.65       674.40
# 2019-05-31 2019-05-31      766.90      821.40     716.40       808.50
# 2019-04-30 2019-04-30      779.95      783.55     737.60       766.90
# 2019-02-28 2019-02-28      721.00      734.35     681.20       709.35
# 2019-01-31 2019-01-31      621.20      726.00     604.65       722.95
#
#             No.of Shares
# Date
# 2019-07-31     7234390.0
# 2019-05-31     9641183.0
# 2019-04-30     7332259.0
# 2019-02-28    11875458.0
# 2019-01-31    16016120.0

# %%
monthly_data = monthly_data.reset_index(drop=True)
monthly_data['Date'] = [mdates.date2num(d) for d in monthly_data['Date']]
quotes = monthly_data.loc[:,:].values
fig, ax = plt.subplots(figsize=(20,10))
candlestick_ohlc(ax, quotes, width=6, colorup='g', colordown='r');
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(stock_name)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

# %%
weekly_data = data.copy()
weekly_data.set_index(weekly_data["Date"],inplace=True)
weekly_data['Open Price'] = weekly_data['Open Price'].resample('W', how='first')
weekly_data['High Price'] = weekly_data['High Price'].resample('W', how='max')
weekly_data['Low Price'] = weekly_data['Low Price'].resample('W', how='count')
weekly_data['Close Price'] = weekly_data['Close Price'].resample('W', how='last')
weekly_data['No.of Shares'] = weekly_data['No.of Shares'].resample('W', how='sum')
weekly_data = weekly_data.dropna()
weekly_data
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).first()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).max()
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   import sys
#                  Date  Open Price  High Price  Low Price  Close Price  \
# Date
# 2016-10-30 2016-10-30      529.95      531.05        6.0        487.8
# 2013-11-03 2013-11-03     1199.10     1260.00        6.0       1219.5
#
#             No.of Shares
# Date
# 2016-10-30     5322694.0
# 2013-11-03     1921862.0

# %%
weekly_data = data.copy()
weekly_data.set_index(weekly_data["Date"],inplace=True)
weekly_dat = pd.DataFrame(np.array([weekly_data["Date"].values,
                                    weekly_data['Open Price'].resample('W', how='first').values,
                                    weekly_data['High Price'].resample('W', how='max').values,
                                    weekly_data['Low Price'].resample('W', how='min').values,
                                    weekly_data['Close Price'].resample('W', how='last').values,
                                    weekly_data['No.of Shares'].resample('W', how='sum').values
                                   ]).T,
                          columns=['Open Price', 'High Price', 'Low Price', 'Close Price','No.of Shares'])
#weekly_dat.set_index(weekly_dat["Date"],inplace=True)
weekly_dat
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).first()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).max()
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).min()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   import sys
#      Open Price  High Price  Low Price  Close Price  No.of Shares
# 0        765.00      822.00     680.00       818.45     2851240.0
# 1        824.80      901.00     818.00       871.80     5921672.0
# 2        878.00      885.00     727.00       739.10     3696795.0
# 3        711.55      857.10     705.15       851.75     6191763.0
# 4        860.10      909.00     847.20       892.50     3692647.0
# 5        894.10      969.00     894.00       917.70     3580829.0
# 6        918.40      930.00     802.35       814.15     4078483.0
# 7        830.00      888.60     797.10       870.30     4141681.0
# 8        860.00      883.00     809.00       879.40     2788671.0
# 9        890.00      938.00     888.00       917.60     2064339.0
# 10       900.00      923.90     881.00       906.95     1583008.0
# 11       918.00      943.90     893.00       902.95     1806657.0
# 12       914.00      927.00     879.00       914.10     1708949.0
# 13       918.00      929.30     904.00       914.40     1455856.0
# 14       920.00     1017.40     915.00      1008.60     3157501.0
# 15       985.00     1028.05     958.10       996.20     2950083.0
# 16      1011.00     1048.00     996.10      1011.25     1834750.0
# 17      1017.00     1026.10     960.00       994.80      993924.0
# 18      1005.00     1005.00     900.00       907.90     2129655.0
# 19       905.00      946.90     889.25       935.25     1306864.0
# 20       940.00     1023.70     939.00       996.60     1901883.0
# 21      1010.00     1014.00     956.10       991.95      964838.0
# 22       990.00     1038.50     937.30       969.40     1872306.0
# 23       982.30     1062.90     981.00      1026.50     1432038.0
# 24      1029.70     1045.00     997.55      1003.65     1057964.0
# 25      1010.00     1014.00     919.20       933.95     1621379.0
# 26       939.65      991.50     926.10       987.15     1424725.0
# 27       990.00      997.40     971.25       988.70      718512.0
# 28       999.00     1020.00     988.00      1013.55      984444.0
# 29      1020.00     1092.95    1018.85      1078.20     1959239.0
# ..          ...         ...        ...          ...           ...
# 498      625.90      672.00     624.00       666.50     4779731.0
# 499      666.50      678.90     652.90       664.30     2075688.0
# 500      661.90      676.00     632.00       667.75     2044716.0
# 501      668.00      726.00     650.00       716.40     7992591.0
# 500      661.90      676.00     632.00       667.75     2044716.0
# 501      668.00      726.00     650.00       716.40     7992591.0
# 502      713.40      734.35     707.40       718.25     2989718.0
# 503      720.85      720.90     681.80       686.55     2149013.0
# 504      687.00      706.70     681.20       703.05     1610540.0
# 505      703.05      727.40     690.50       703.10     2322771.0
# 506      704.60      738.40     701.05       732.35     2300599.0
# 507      731.60      750.90     731.00       735.70     3496248.0
# 508      738.65      766.70     738.65       757.35     5416351.0
# 509      753.85      788.55     741.00       776.10     2254459.0
# 510      779.95      783.55     756.05       761.95     1755577.0
# 511      764.95      767.80     747.05       764.15     1879891.0
# 512      764.15      779.00     761.00       771.20      932936.0
# 513      770.25      770.25     737.60       760.20     2448483.0
# 514      760.20      769.55     748.40       757.40      867993.0
# 515      748.40      755.35     729.00       733.65     1434894.0
# 516      730.95      751.50     716.40       748.15     2211484.0
# 517      764.50      803.70     762.00       793.65     3970054.0
# 518      793.65      821.40     787.60       808.50     1472130.0
# 519      810.10      826.55     801.65       804.20     1509282.0
# 520      810.00      822.90     796.75       800.15     1195444.0
# 521      801.00      802.40     759.00       771.95     2101523.0
# 522      771.00      812.90     757.00       807.65     1590052.0
# 523      810.00      819.05     800.70       805.95     1127191.0
# 524      803.40      804.45     751.10       755.45     1229517.0
# 525      757.95      765.60     723.25       729.45     1567893.0
# 526      732.75      739.30     706.55       729.85     1326348.0
# 527      745.00      745.00     657.65       674.40     1983441.0
#
# [528 rows x 5 columns]

# %%
weekly_data = weekly_data.reset_index(drop=True)
weekly_data['Date'] = [mdates.date2num(d) for d in weekly_data['Date']]
quotes = weekly_data.loc[:,:].values
fig, ax = plt.subplots(figsize=(20,10))
candlestick_ohlc(ax, quotes, width=6, colorup='g', colordown='r');
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(stock_name)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

# %%
train_data = data[0:int(len(data)*0.8)]
test_data = data[int(len(data)*0.8):]
plt.figure(figsize=(20,10))
plt.title(stock_name)
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(train_data['Close Price'], 'blue', label='Training Data')
plt.plot(test_data['Close Price'], 'green', label='Testing Data')

# %%
def smape_kun(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) +       np.abs(y_true))))

# %%
history = [x for x in train_data['Close Price'].values]
print(type(history))
pred = []
for i in range(len(train_data['Close Price'].values)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    pred.append(yhat)
    obs = test_data['Close Price'].values[i]
    history.append(obs)
error = mean_squared_error(test_data['Close Price'].values, pred)
print('Mean Squared Error: ',error)
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-224-04c541d5dcf2> in <module>
#       8     yhat = output[0]
#       9     pred.append(yhat)
# ---> 10     obs = test_data['Close Price'].values[i]
#      11     history.append(obs)
#      12 error = mean_squared_error(test_data['Close Price'].values, pred)
#
# IndexError: index 502 is out of bounds for axis 0 with size 502

# %%
plt.figure(figsize=(20,10))
plt.plot(train_data['Close Price'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', label='Predicted Price')
plt.plot(test_data.index, test_data['Close Price'], color='red', label='Actual Price')
plt.title(stock_name)
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-225-2dd2d3bb7a64> in <module>
#       1 plt.figure(figsize=(20,10))
#       2 plt.plot(train_data['Close Price'], 'green', color='blue', label='Training Data')
# ----> 3 plt.plot(test_data.index, predictions, color='green', label='Predicted Price')
#       4 plt.plot(test_data.index, test_data['Close Price'], color='red', label='Actual Price')
#       5 plt.title(stock_name)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (502,) and (0,)
